# %% [markdown]
# # <center>Pandas Assignment</center>

# %% [markdown]
# Import pandas and numpy with their aliases

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Create a variable a = pd.Series([ 100, 200, 300, 400])

# %%
a = pd.Series([100, 200, 300, 400])

# %% [markdown]
# Print a, and data type

# %%
print(a)
print(type(a))
# Out:
# 0    100
# 1    200
# 2    300
# 3    400
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Using indexing access the element 300 from the series a.

# %%
element = a[2]
print(element)
# Out:
# 300

# %% [markdown]
# What are the values of index for series a?

# %%
print(a.index)
print(list(a.index))
# Out:
# RangeIndex(start=0, stop=4, step=1)
# [0, 1, 2, 3]

# %% [markdown]
# Change the index to  ['c', 'a', 'b', 'd']

# %%
a.index = ['c', 'a', 'b', 'd']
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# dtype: int64

# %% [markdown]
# Access the value in the series with index 'd'

# %%
print(a['d'])
# Out:
# 400

# %% [markdown]
# Sort the values wrt to the index and print it

# %%
sorted_a = a.sort_index()
print(sorted_a)
# Out:
# a    200
# b    300
# c    100
# d    400
# dtype: int64

# %% [markdown]
# Create a new Pandas Series b having index as 'e', 'f', and 'g' and value 800,450,100 and print it

# %%
b = pd.Series([800, 450, 100], index = ['e', 'f', 'g'])
print(b)
# Out:
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Append b series at the end of a series

# %%
a = pd.concat([a, b])

# %%
#print a again after appending b into it
print(a)
# Out:
# c    100
# a    200
# b    300
# d    400
# e    800
# f    450
# g    100
# dtype: int64

# %% [markdown]
# Sort the values in descending order of a and print the index of the sorted series

# %%
a = a.sort_values(ascending = False)

# %%
print(a)
# Out:
# e    800
# f    450
# d    400
# b    300
# a    200
# c    100
# g    100
# dtype: int64

# %% [markdown]
# ## Pandas DataFrame

# %% [markdown]
# ### Part 1

# %% [markdown]
# Create a pandas dataframe df from the series 'a' that we used in the last section, print the dataframe

# %%
df = pd.DataFrame(a)

# %%
print(df)
# Out:
#      0
# e  800
# f  450
# d  400
# b  300
# a  200
# c  100
# g  100

# %% [markdown]
# What is the shape of the datafarme <br>
# (also, what does it imply?)

# %%
print(df.shape)
# Out:
# (7, 1)

# %% [markdown]
# Hey! remember shape (7,1) implies dataframe has 7 rows and 1 column.

# %% [markdown]
# What is the index of the dataframe, is it same as the series 'a'

# %%
# yep its same as the series.
print(df.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# print the head and tail of the dataframe. <br>
# Additional - (what does head and tali represent?)

# %%
# Head
print(df.head(1))
# Out:
#      0
# e  800

# %%
# Tail
print(df.tail(1))
# Out:
#      0
# g  100

# %% [markdown]
# Rename the column of the dataframe as 'points'

# %%
df = df.rename(columns={0:'points'})
print(df)
# Out:
#    points
# e     800
# f     450
# d     400
# b     300
# a     200
# c     100
# g     100

# %% [markdown]
# Create another Series 'fruits', which contains random names of fruits from ['orange','mango','apple']. The series should contain 7 elements, randomly selected from ['orange','mango','apple']

# %%
#Create fruits array

fruits = ['orange', 'manngo', 'apple']

# %%
#Create series fruits out of fruits array

fruits = np.random.choice(fruits, size=7)
fruits = pd.Series(fruits)
print(fruits)
# Out:
# 0    manngo
# 1    manngo
# 2     apple
# 3     apple
# 4     apple
# 5    orange
# 6     apple
# dtype: object

# %% [markdown]
# Change the index of fruits to the index of dataframe df

# %%
fruits.index = df.index
print(fruits.index)
print(df.index)
# Out:
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')
# Index(['e', 'f', 'd', 'b', 'a', 'c', 'g'], dtype='object')

# %% [markdown]
# Add this fruits series as a new column to the dataframe df with its column name as 'fruits'
# <br>print the head of the dataframe to verify

# %%
df['fruits'] = fruits

# %%
print(df.head())
# Out:
#    points  fruits
# e     800  manngo
# f     450  manngo
# d     400   apple
# b     300   apple
# a     200   apple

# %% [markdown]
# ## Pandas Concatenation

# %% [markdown]
# Create a dataframe  d1 where the cols are  ‘city’ : [‘Chandigarh’, ‘Delhi’, ‘Kanpur’, ‘Chennai’, ‘Manali’ ] and ‘Temperature’ : [15, 22, 20, 26,-2]

# %%
d1 = {
    'city' : ['Chandigarh', 'Delhi', 'Kanpur', 'Chennai', 'Manali'],
    'Temperature' : [15, 22, 20, 26,-2]
}
d1 = pd.DataFrame(d1)

# %% [markdown]
# Print(d1)

# %%
print(d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22
# 2      Kanpur           20
# 3     Chennai           26
# 4      Manali           -2

# %% [markdown]
# What is the shape of d1.

# %%
print(d1.shape)
# Out:
# (5, 2)

# %% [markdown]
# Set city = d1['city']

# %%
city = d1['city']

# %% [markdown]
# print city <br>
# What is the type of city.

# %%
print(city)
print(type(city))
# Out:
# 0    Chandigarh
# 1         Delhi
# 2        Kanpur
# 3       Chennai
# 4        Manali
# Name: city, dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Create another datafeame 'd2' where the columns are <br>
# 'city' - ['Bengalaru','Coimbatore','Srirangam','Pondicherry'] <br>
# 'Temperature' - [24,35,36,39]

# %%
d2 = {
    'city' : ['Bangalaru', 'Coimbatore', 'Srirangam', 'Pondicherry'],
    'Temperature' : [24, 35, 36, 39]
}

d2 = pd.DataFrame(d2)
print(d2)
# Out:
#           city  Temperature
# 0    Bangalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# print the shape of this dataframe

# %%
print(d2.shape)
# Out:
# (4, 2)

# %% [markdown]
# merge the two dataframes together, save it in a new dataframe named 'd3'

# %%
d3 = pd.concat([d1, d2])
print(d3)
# Out:
#           city  Temperature
# 0   Chandigarh           15
# 1        Delhi           22
# 2       Kanpur           20
# 3      Chennai           26
# 4       Manali           -2
# 0    Bangalaru           24
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# Select the part of the dataframe such that it contains cities wherer temp is less then or equal to 20 <br>
# How many cities are there?

# %%
cool_cities = d3[d3['Temperature']<=20]
print(cool_cities)

length = len(cool_cities)
print(f'\n There are {length} cities')
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 2      Kanpur           20
# 4      Manali           -2
#
#  There are 3 cities

# %% [markdown]
# Select the part of the dataframe such that it contains the cities where tempearature greater than or equal to 35

# %%
hot_cities = d3[d3['Temperature']>=35]
print(hot_cities)
# Out:
#           city  Temperature
# 1   Coimbatore           35
# 2    Srirangam           36
# 3  Pondicherry           39

# %% [markdown]
# ## Applying functions to columns and creating new columns

# %% [markdown]
# We need to create another column in d3, which contains  a boolean value for each city to indicate whether it's a union territory or not.
# - HINT: Chandigarh, Pondicherry and Delhi are only 3 union territories here.

# %%
# write function here
union_territories = ['Chandigarh', 'Pondicherry', 'Delhi']
def is_ut(city_name):
    # write code below
    if city_name in union_territories:
        return True
    else:
        return False
    
d3['is_ut'] = d3['city'].apply(is_ut)

# %%
# print d3
print(d3)
# Out:
#           city  Temperature  is_ut
# 0   Chandigarh           15   True
# 1        Delhi           22   True
# 2       Kanpur           20  False
# 3      Chennai           26  False
# 4       Manali           -2  False
# 0    Bangalaru           24  False
# 1   Coimbatore           35  False
# 2    Srirangam           36  False
# 3  Pondicherry           39   True

# %% [markdown]
# The temperatures mentioned in ‘Temperature’ column are mentioned in Celsius, we need another column which contains the same in Fahrenheit.

# %% [markdown]
# HINT -
# - Define a function c_to_f which takes input temp in celsius and returns a value with temperature in Fahrenheit.
# - To check: c_to_f(10) should return 50.

# %%
# write function here
def c_to_f(celsius):
    return (celsius * 9/5) + 32

# %%
# check function c_to_f(10)
print(f'Check function celsius to fahrenheit {c_to_f(10)}F')
# Out:
# Check function celsius to fahrenheit 50.0F

# %%
# apply function c_to_f to d3 to create a column 'temp_farenhiet'
d3['Temp_Fahrenheit'] = d3['Temperature'].apply(c_to_f)
print(d3)
# Out:
#           city  Temperature  is_ut  Temp_Fahrenheit
# 0   Chandigarh           15   True             59.0
# 1        Delhi           22   True             71.6
# 2       Kanpur           20  False             68.0
# 3      Chennai           26  False             78.8
# 4       Manali           -2  False             28.4
# 0    Bangalaru           24  False             75.2
# 1   Coimbatore           35  False             95.0
# 2    Srirangam           36  False             96.8
# 3  Pondicherry           39   True            102.2

# %% [markdown]
# ## Indexing and selecting rows in DataFrame

# %% [markdown]
# Select subset of the dataframe d1 such that it contains the cities which are union territories.

# %%
ut_cities_d1 = d1[d1['city'].isin(union_territories)]
print(ut_cities_d1)
# Out:
#          city  Temperature
# 0  Chandigarh           15
# 1       Delhi           22

# %% [markdown]
# Select a subset of the dataframe d1 such that it contains the cities which only have temperature above 90 Farenhiet.

# %%
d1['Temp_Fahrenheit'] = (d1['Temperature'] * 9/5) + 32
hot_cities = d1[d1['Temp_Fahrenheit']>90]
print(hot_cities)
# Out:
# Empty DataFrame
# Columns: [city, Temperature, Temp_Fahrenheit]
# Index: []

# %% [markdown]
# Select only the first three rows of the dataframe d1.

# %%
first_three = d1.head(3)
print(first_three)
# Out:
#          city  Temperature  Temp_Fahrenheit
# 0  Chandigarh           15             59.0
# 1       Delhi           22             71.6
# 2      Kanpur           20             68.0

# %% [markdown]
# Select all the rows and last two columns in the dataframe.

# %%
last_two_columns = d1.iloc[:, -2:]
print(last_two_columns)
# Out:
#    Temperature  Temp_Fahrenheit
# 0           15             59.0
# 1           22             71.6
# 2           20             68.0
# 3           26             78.8
# 4           -2             28.4

# %% [markdown]
# ## Groupby

# %%
# Create a dataframe using dictionary of your choice

data = {
    'Category': ['Food', 'Transport', 'Food', 'Utilities', 'Transport', 'Food'],
    'Amount': [150, 50, 200, 1200, 80, 300],
    'Payment_Method': ['Cash', 'Card', 'Card', 'Bank Transfer', 'Cash', 'Card']
}

df_data = pd.DataFrame(data)
print(df_data)
# Out:
#     Category  Amount Payment_Method
# 0       Food     150           Cash
# 1  Transport      50           Card
# 2       Food     200           Card
# 3  Utilities    1200  Bank Transfer
# 4  Transport      80           Cash
# 5       Food     300           Card

# %%
# Use Groupby of single column with aggregate sum()
category_sum = df_data.groupby('Category')['Amount'].sum()
print(category_sum)
# Out:
# Category
# Food          650
# Transport     130
# Utilities    1200
# Name: Amount, dtype: int64

# %%
# Use Groupby of single column with aggregate count()
payment_count = df_data.groupby('Category')['Amount'].count()
print(payment_count)
# Out:
# Category
# Food         3
# Transport    2
# Utilities    1
# Name: Amount, dtype: int64

# %%
# Use Groupby of single column with aggregate min() and max()
min_data = df_data.groupby('Category')['Amount'].min()
print(f'Minimun data {min_data}')

max_data = df_data.groupby('Category')['Amount'].max()
print(f'\n Maximum data {max_data}')
# Out:
# Minimun data Category
# Food          150
# Transport      50
# Utilities    1200
# Name: Amount, dtype: int64
#
#  Maximum data Category
# Food          300
# Transport      80
# Utilities    1200
# Name: Amount, dtype: int64

# %%
# Use Groupby of any 2 columns with aggregate mean()
avg = df_data.groupby(['Category', 'Payment_Method'])['Amount'].mean()
print(avg)
# Out:
# Category   Payment_Method
# Food       Card               250.0
#            Cash               150.0
# Transport  Card                50.0
#            Cash                80.0
# Utilities  Bank Transfer     1200.0
# Name: Amount, dtype: float64

# %%
# Use Groupby of any 2 columns with aggregate min() and max()
min = df_data.groupby(['Category', 'Payment_Method'])['Amount'].min()
print(f'Minimum \n {min}')

max = df_data.groupby(['Category', 'Payment_Method'])['Amount'].max()
print(f'\n Maximum \n {max}')
# Out:
# Minimum
#  Category   Payment_Method
# Food       Card               200
#            Cash               150
# Transport  Card                50
#            Cash                80
# Utilities  Bank Transfer     1200
# Name: Amount, dtype: int64
#
#  Maximum
#  Category   Payment_Method
# Food       Card               300
#            Cash               150
# Transport  Card                50
#            Cash                80
# Utilities  Bank Transfer     1200
# Name: Amount, dtype: int64

# %% [markdown]
# ## Data Range

# %% [markdown]
# Create a pandas daterange where starting date is 1st of January,2020 and end date is 1st of April 2021, store it in a new variable named 'a'

# %%
a = pd.date_range(start='2020-01-01', end='2021-04-01')

# %% [markdown]
# print a

# %%
print(a)
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2021-03-23', '2021-03-24', '2021-03-25', '2021-03-26',
#                '2021-03-27', '2021-03-28', '2021-03-29', '2021-03-30',
#                '2021-03-31', '2021-04-01'],
#               dtype='datetime64[ns]', length=457, freq='D')

# %% [markdown]
# What is the len of a?

# %%
print(len(a))
# Out:
# 457

# %% [markdown]
# What is the type of a?

# %%
print(type(a))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
